# %%
pip install pandas numpy matplotlib seaborn scikit-learn plotly ipykernel tensorflow torch torchvision torchaudio transformers xgboost lightgbm catboost statsmodels prophet xarray netcdf4 h5netcdf dask pyarrow requests tqdm opencv-python nltk spacy
